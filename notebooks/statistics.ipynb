# %% [markdown]
# ## Look for Visual Statistics

# %%
import os, config
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_split_df = pd.read_csv(os.path.join(config.DATA_DIR, 'train_split_Depression_AVEC2017.csv'))

# %%
train_split_df = train_split_df[['Participant_ID', 'PHQ8_Binary']]
train_split_df['PHQ8_String'] = train_split_df.PHQ8_Binary.apply(lambda x : 'depression' if x else 'healthy')
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_41880\3917057887.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_split_df['PHQ8_String'] = train_split_df.PHQ8_Binary.apply(lambda x : 'depression' if x else 'healthy')
