# %%
import torch, config, os
best_model = torch.load(os.path.join(config.ROOT_DIR, 'checkpoints_nce', 'multimodal_nce_4', 'best_model.pth'))

# %%
best_model.keys()
# Out:
# dict_keys(['epoch', 'model_state_dict', 'optimizer_state_dict', 'scheduler_state_dict', 'queue_x_state_dict', 'queue_x2_state_dict', 'config', 'history'])

# %%
best_model['config']
# Out:
# {'training': {'lr': 0.001,
#   'weight-decay': 0.0001,
#   'bs': 128,
#   'workers': 0,
#   'scheduler': 'steplr',
#   'gamma': 0.5,
#   'step-size': 25,
#   'q_size': 4096,
#   'T': 0.07,
#   'M': 0.995,
#   'lambda': 0.5},
#  'model': {'h_dim': 128, 'o_dim': 128, 'depth': 2, 'dropout': 0.1}}
